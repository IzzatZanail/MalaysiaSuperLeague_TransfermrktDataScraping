# %%
########################################################
# Author: Izzat Zanail - izzat.zanail@gmail.com
# Language: Python 3.12
# Created: 2024-03-21
# Updated: 2024-11-03
# Project: Malaysia Super League Data Analysis
# Description: MSL Football Clubs Data Scraping and Analysis from Transfermarkt website
########################################################

# %%
# Import libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import math
import os

# %%
# Path

path_csv_datascraping = os.getcwd() + '\\datacsv'
os.chdir('../')
os.chdir('MalaysiaSuperLeague_DataAnalysis\MalaysiaSuperLeagueDataAnalysis')
path_csv_dataanalysis = os.getcwd() + '\\datacsv'
os.chdir('../../')
os.chdir('MalaysiaSuperLeague_TransfermrktDataScraping')
path_working_directory = os.getcwd()

# %%
# Change number format for easier read

pd.options.display.float_format = '{:,.0f}'.format

# %%
# # Scrape MSL teams' data

season_year = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
trsfrmkt_msl_link = 'https://www.transfermarkt.com/malaysia-super-league/startseite/wettbewerb/MYS1/plus/?saison_id='

YearList = []
TeamsList = []
TeamsListCleaned = []
TeamSquadSize = []
TeamNoForeigners = []
TeamMarketValue = []
TeamLinksList = []
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

for year in range(0, len(season_year)):
    page_year = trsfrmkt_msl_link + str(season_year[year])
    pageTree = requests.get(page_year, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')
    
    Teams = pageSoup.find_all('td', {'class': 'hauptlink no-border-links'})
    SquadSize = pageSoup.find_all('td', {'class': 'zentriert'})
    NoForeigners = pageSoup.find_all('td', {'class': 'zentriert'})
    MarketValue = pageSoup.find_all('td', {'class': 'rechts'})
    TeamLinks = pageSoup.find_all('td', {'class': 'hauptlink no-border-links'})
    
    for i in range(0, len(Teams)):
        str_Teams = str(Teams[i]).split('title="',1)[1].split('">',1)[0]
        TeamsList.append(str_Teams)
    for i in range(4, len(Teams)*4+4, 4):
        str_SquadSize = str(SquadSize[i]).split('>', 2)[2].split('<')[0]
        TeamSquadSize.append(str_SquadSize)
    for i in range(6, len(Teams)*4+6, 4):
        str_NoForeigners = str(NoForeigners[i]).split('>')[1].split('<')[0]
        TeamNoForeigners.append(str_NoForeigners)
    for i in range(3, len(Teams)*2+2, 2):
        str_MarketValue = str(MarketValue[i]).split('€')[1].split('<')[0]
        if 'k' in str_MarketValue:
            str_mv = str_MarketValue.split('k')[0]
            flt_mv = float(str_mv)*1000
            TeamMarketValue.append(flt_mv)
        elif 'm' in str_MarketValue:
            str_mv = str_MarketValue.split('m')[0]
            flt_mv = float(str_mv)*1000000
            TeamMarketValue.append(flt_mv)
        else:
            TeamMarketValue.append(float(flt_mv))
    for i in range(0, len(TeamLinks)):
        str_TeamLinks = str(TeamLinks[i]).split('a href="',1)[1].split('"',1)[0]
        TeamLinksList.append("https://www.transfermarkt.com" + str_TeamLinks)
    for i in range(0, len(Teams)):
        YearList.append(str(season_year[year] + 1))

# Data cleaning - clean Team names
for i in range(0, len(TeamsList)):
    if "Johor Darul Ta'zim" in TeamsList[i]:
        new_name = "Johor Darul Ta'zim FC"
        TeamsListCleaned.append(new_name)
    elif "Kedah FA" in TeamsList[i]:
        new_name = 'Kedah Darul Aman FC'
        TeamsListCleaned.append(new_name)
    elif "Kelantan United" in TeamsList[i]:
        new_name = 'Kelantan Darul Naim FC'
        TeamsListCleaned.append(new_name)
    elif "Kelantan Darul Naim" in TeamsList[i]:
        new_name = 'Kelantan Darul Naim FC'
        TeamsListCleaned.append(new_name)
    elif "Kuching City" in TeamsList[i]:
        new_name = 'Kuching City FC'
        TeamsListCleaned.append(new_name)
    else:
        TeamsListCleaned.append(TeamsList[i])

# %%
# Create Dataframe for the extracted links

df_msl_teams = pd.DataFrame({
                    "SEASON":YearList,
                    "TEAM":TeamsListCleaned,
                    #"TEAM_CLEANED":TeamsListCleaned,
                    "SQUAD_SIZE":TeamSquadSize,
                    "NO_OF_FOREIGNERS":TeamNoForeigners,
                    "MARKET_VALUE_EUR":TeamMarketValue,
                    "LINK":TeamLinksList
})
# set dtypes for each column
df_msl_teams['SEASON'] = df_msl_teams['SEASON'].astype(str)
df_msl_teams['TEAM'] = df_msl_teams['TEAM'].astype(str)
df_msl_teams['SQUAD_SIZE'] = df_msl_teams['SQUAD_SIZE'].astype(int)
df_msl_teams['NO_OF_FOREIGNERS'] = df_msl_teams['NO_OF_FOREIGNERS'].astype(int)
df_msl_teams['LINK'] = df_msl_teams['LINK'].astype(str)

# remove duplicated rows of Year 2025
df_msl_teams = df_msl_teams[df_msl_teams['SEASON'] != '2025']

df_msl_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SEASON            99 non-null     object
#  1   TEAM              99 non-null     object
#  2   SQUAD_SIZE        99 non-null     int32
#  3   NO_OF_FOREIGNERS  99 non-null     int32
#  4   MARKET_VALUE_EUR  99 non-null     float64
#  5   LINK              99 non-null     object
# dtypes: float64(1), int32(2), object(3)
# memory usage: 4.6+ KB

# %%
df_msl_teams.head(n=10)
# Out:
#   SEASON                   TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
# 0   2017  Johor Darul Ta'zim FC          36                 9
# 1   2017       Melaka United FC          52                10
# 2   2017    Kedah Darul Aman FC          33                 3
# 3   2017            Selangor FC          35                 8
# 4   2017          Sri Pahang FC          33                 5
# 5   2017         Selangor FC II          38                 7
# 6   2017            Kelantan FC          45                 9
# 7   2017       Terengganu FC II          36                 6
# 8   2017        FELDA United FC          35                 8
# 9   2017              Penang FC          41                 8
#
#    MARKET_VALUE_EUR                                               LINK
# 0         6,630,000  https://www.transfermarkt.com/johor-darul-tazi...
# 1         3,130,000  https://www.transfermarkt.com/melaka-united-fc...
# 2         3,030,000  https://www.transfermarkt.com/kedah-darul-aman...
# 3         2,980,000  https://www.transfermarkt.com/selangor-fc/star...
# 4         2,850,000  https://www.transfermarkt.com/sri-pahang-fc/st...
# 5         2,830,000  https://www.transfermarkt.com/selangor-fa-ii/s...
# 6         2,730,000  https://www.transfermarkt.com/kelantan-fa/star...
# 7         2,580,000  https://www.transfermarkt.com/terengganu-fc-ii...
# 8         2,250,000  https://www.transfermarkt.com/felda-united-fc/...
# 9         2,250,000  https://www.transfermarkt.com/penang-fc/starts...

# %%
df_msl_teams.tail(n=20)
# Out:
#    SEASON                    TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
# 79   2023      Negeri Sembilan FC          36                 7
# 80   2023         Kuching City FC          44                14
# 81   2023               Penang FC          40                10
# 82   2023                Perak FC          51                 8
# 83   2023  Kelantan Darul Naim FC          35                10
# 84   2023             Kelantan FC          56                10
# 85   2023                 PDRM FC          36                 9
# 86   2024   Johor Darul Ta'zim FC          35                15
# 87   2024             Selangor FC          34                11
# 88   2024           Terengganu FC          30                 8
# 89   2024                Sabah FC          34                 8
# 90   2024           Sri Pahang FC          26                 5
# 91   2024     Kedah Darul Aman FC          40                 5
# 92   2024    Kuala Lumpur City FC          29                 5
# 93   2024                Perak FC          28                 8
# 94   2024         Kuching City FC          37                10
# 95   2024  Kelantan Darul Naim FC          38                10
# 96   2024                 PDRM FC          35                 9
# 97   2024      Negeri Sembilan FC          30                 8
# 98   2024               Penang FC          30                 5
#
#     MARKET_VALUE_EUR                                               LINK
# 79         3,790,000  https://www.transfermarkt.com/negeri-sembilan-...
# 80         3,470,000  https://www.transfermarkt.com/kuching-city/sta...
# 81         3,430,000  https://www.transfermarkt.com/penang-fc/starts...
# 82         3,230,000  https://www.transfermarkt.com/perak-fc/startse...
# 83         2,620,000  https://www.transfermarkt.com/kelantan-united/...
# 84         2,500,000  https://www.transfermarkt.com/kelantan-fa/star...
# 85         2,410,000  https://www.transfermarkt.com/pdrm-fa/startsei...
# 86        10,830,000  https://www.transfermarkt.com/johor-darul-tazi...
# 87         6,980,000  https://www.transfermarkt.com/selangor-fc/star...
# 88         4,700,000  https://www.transfermarkt.com/terengganu-fc/st...
# 89         3,890,000  https://www.transfermarkt.com/sabah-fc/startse...
# 90         3,800,000  https://www.transfermarkt.com/sri-pahang-fc/st...
# 91         3,750,000  https://www.transfermarkt.com/kedah-darul-aman...
# 92         3,380,000  https://www.transfermarkt.com/kuala-lumpur-cit...
# 93         3,030,000  https://www.transfermarkt.com/perak-fc/startse...
# 94         2,920,000  https://www.transfermarkt.com/kuching-city/sta...
# 95         2,610,000  https://www.transfermarkt.com/kelantan-united/...
# 96         2,550,000  https://www.transfermarkt.com/pdrm-fa/startsei...
# 97         2,480,000  https://www.transfermarkt.com/negeri-sembilan-...
# 98         2,450,000  https://www.transfermarkt.com/penang-fc/starts...

# %%
# Export the DataFrame to csv file

df_msl_teams.to_csv(path_csv_datascraping + '\\MSL_TeamPages.csv', index=False)
df_msl_teams.to_csv(path_csv_dataanalysis + '\\MSL_TeamPages.csv', index=False)

# %%
# Scrape MSL players' data

# Create lists

SeasonList = []
PlayerTeamsList = []
PlayersList = []
PlayerLinksList = []
NumberList = []
AgeList = []
PositionList = []
NationList = []
ValueList = []
grouped_positionList = []
cleaned_values = []
cleaned_team_names = []

# Scrape player data, from links that were previously scraped

for link in range(0, len(TeamLinksList)):
    page = TeamLinksList[link]
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')
    
    TeamNames = pageSoup.find_all("h1", {"class": "data-header__headline-wrapper data-header__headline-wrapper--oswald"})
    Players = pageSoup.find_all("img", {"class": "bilderrahmen-fixed lazy lazy"})
    PlayerLinks = pageSoup.find_all("td", {"class": "hauptlink"})
    Numbers = pageSoup.find_all("div", {"class": "rn_nummer"})
    Age = pageSoup.find_all("td", {"class": "zentriert"})
    Positions = pageSoup.find_all("table", {"class": "inline-table"})
    Nationality = pageSoup.find_all('img', {'class': 'flaggenrahmen'})
    Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
    
    season_year = str(int(TeamLinksList[link].split("/", 8)[8]))
    
    #if season 2024, skip 3 rows, else, skip 4 rows 
    if season_year == "2024":
        r = 3
    else:
        r = 4
    
    for i in range(0, len(Players)):
        SeasonList.append(season_year)
    
    for i in range(0, len(Players)):
        str_Team = str(TeamNames).split('>')[1].split('\n            ')[1].split('        </h1')[0]
        PlayerTeamsList.append(str_Team)
    
    for i in range(0, len(Players)):
        str_Players = str(Players[i]).split('" class',1)[0].split('<img alt="',1)[1]
        PlayersList.append(str_Players)

    for i in range(0, len(Players)*2, 2):
        str_PlayerLinks = str(PlayerLinks[i]).split("\n", 1)[1].split('<a href=')[1].split("\n")[0].split(">")[0].split('"')[1]
        PlayerLinksList.append('https://www.transfermarkt.com' + str_PlayerLinks)
    
    for i in range(0, len(Numbers)):
        str_Numbers = str(Numbers[i]).split('class="rn_nummer">',1)[1].split('</div>',1)[0]
        NumberList.append(str_Numbers)
           
    for i in range(0, len(Positions)):
        str_Position = str(Positions[i]).split('<td>', 1)[1].split('</td>', 1)[0].split('\n ', 1)[1].split('           ', 1)[1].split('        ',1)[0]
        PositionList.append(str_Position)
    
    # Convert specific position names into a more general name - Marked as "Position Type"
    for j in range(0, len(Positions)):
        if 'Striker' in PositionList[j]:
            grouped_positionList.append('Forwards')
        elif 'Forward' in PositionList[j]:
            grouped_positionList.append('Forwards')
        elif 'Midfield' in PositionList[j]:
            grouped_positionList.append('Midfielders')
        elif 'Midfielder' in PositionList[j]:
            grouped_positionList.append('Midfielders')
        elif 'Winger' in PositionList[j]:
            grouped_positionList.append('Midfielders')
        elif 'Back' in PositionList[j]:
            grouped_positionList.append('Defenders')
        elif 'Defender' in PositionList[j]:
            grouped_positionList.append('Defenders')
        else:
            grouped_positionList.append(PositionList[j])

    for i in range(1, (len(Players)*r), r):
        str_Age = str(Age[i]).split("(",1)[1].split(")",1)[0]
        AgeList.append(str_Age)
    
    for i in range(0, len(Values)):
        ValueList.append(Values[i].text)
        
# Data cleaning - change "Value" datatype from string type to float type
for a in range(0, len(ValueList)):
    if 'k' in ValueList[a]:
        str_a = str(ValueList[a]).split('€')[1].split('k')[0]
        flt_a = float(str_a)*1000
        cleaned_values.append(flt_a)
    elif 'm' in ValueList[a]:
        str_a = str(ValueList[a]).split('€')[1].split('m')[0]
        flt_a = float(str_a)*1000000
        cleaned_values.append(flt_a)
    else:
        cleaned_values.append(float(a))

# Data cleaning - clean Team names
for b in range(0, len(PlayerTeamsList)):
    if "Johor Darul Ta'zim" in PlayerTeamsList[b]:
        new_name = "Johor Darul Ta'zim FC"
        cleaned_team_names.append(new_name)
    elif "Kedah FA" in PlayerTeamsList[b]:
        new_name = 'Kedah Darul Aman FC'
        cleaned_team_names.append(new_name)
    elif "Kelantan United" in PlayerTeamsList[b]:
        new_name = 'Kelantan Darul Naim FC'
        cleaned_team_names.append(new_name)
    elif "Kelantan Darul Naim" in PlayerTeamsList[b]:
        new_name = 'Kelantan Darul Naim FC'
        cleaned_team_names.append(new_name)
    elif "Kuching City" in PlayerTeamsList[b]:
        new_name = 'Kuching City FC'
        cleaned_team_names.append(new_name)
    else:
        cleaned_team_names.append(PlayerTeamsList[b])

# %%
# Create DataFrame for full extracted data

df_msl_player = pd.DataFrame({
                         "SEASON":SeasonList,
                         "TEAM":PlayerTeamsList,
                         "TEAM_CLEANED":cleaned_team_names,
                         "PLAYER":PlayersList,
                         "NUMBER":NumberList,
                         "AGE":AgeList,
                         "POSITION":PositionList,
                         "POSITION_TYPE":grouped_positionList,
                         "VALUE_EUR":ValueList,
                         "VALUE_EUR_1":cleaned_values,
                         "PLAYER_LINK":PlayerLinksList                   
                        })
df_msl_player

# clean AGE
df_msl_player['AGE'] = np.where(df_msl_player['AGE'] == '-', int(0), df_msl_player['AGE'])
df_msl_player['AGE'] = df_msl_player['AGE'].astype('int')

df_msl_player = df_msl_player[df_msl_player['AGE'] != 0]

# remove duplicated rows of Year 2025 & reset index
df_msl_player = df_msl_player.drop_duplicates().reset_index()

# remove column 'index'
df_msl_player = df_msl_player.drop(columns=['index'])

# clean VALUE_EUR
df_msl_player['VALUE_EUR'] = np.where(df_msl_player['VALUE_EUR'] == '-', '€0n', df_msl_player['VALUE_EUR'])

df_msl_player['VALUE_EUR_CLEANED'] = ''
for i in range(0, len(df_msl_player)):
    val = df_msl_player.loc[i, 'VALUE_EUR'].split('€')[1]

    res_k = 'k' in val
    res_m = 'm' in val
    res_nothing = 'n' in val

    if res_k:
        new_val = float(val.split('k')[0]) * 1000
    elif res_m:
        new_val = float(val.split('m')[0]) * 1000000
    elif res_nothing:
        new_val = float(val.split('n')[0])*0

    df_msl_player.loc[i, 'VALUE_EUR_CLEANED'] = new_val

df_msl_player['VALUE_EUR'] = df_msl_player['VALUE_EUR_1']

# remove column 'VALUE_EUR_CLEANED'
df_msl_player = df_msl_player.drop(columns=['VALUE_EUR_CLEANED', 'VALUE_EUR_1'])

df_msl_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3433 entries, 0 to 3432
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SEASON         3433 non-null   object
#  1   TEAM           3433 non-null   object
#  2   TEAM_CLEANED   3433 non-null   object
#  3   PLAYER         3433 non-null   object
#  4   NUMBER         3433 non-null   object
#  5   AGE            3433 non-null   int32
#  6   POSITION       3433 non-null   object
#  7   POSITION_TYPE  3433 non-null   object
#  8   VALUE_EUR      3433 non-null   float64
#  9   PLAYER_LINK    3433 non-null   object
# dtypes: float64(1), int32(1), object(8)
# memory usage: 254.9+ KB

# %%
# Create Player-Individual Page Links dataframe

player_links = df_msl_player[['PLAYER', 'PLAYER_LINK']].drop_duplicates(subset='PLAYER').reset_index()
player_links = player_links[['PLAYER', 'PLAYER_LINK']]

player_links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321 entries, 0 to 1320
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER       1321 non-null   object
#  1   PLAYER_LINK  1321 non-null   object
# dtypes: object(2)
# memory usage: 20.8+ KB

# %%
# Create Player's nationality dataframe - nationality scraped from each individual page in Transfermarkt website

PlayerNameList = []
PlayerNationalityList = []

total_list = len(player_links['PLAYER_LINK'])

for i in range (0, total_list, 1):
    page = player_links['PLAYER_LINK'][i]
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')
    
    Nationality = pageSoup.find_all('span', {'class': 'data-header__content', 'itemprop': 'nationality'})

    PlayerFullName = player_links['PLAYER'][i]
    PlayerNameList.append(PlayerFullName)

    Nation = str(Nationality[0]).split('img alt="')[1].split('" class=')[0]
    PlayerNationalityList.append(Nation)

    print('Player ' + str(i + 1) + ' of ' +  str(total_list) + '. Progress: ' + str(round((i+1/total_list)*100,2)) + '%. Player: ' + PlayerFullName + ', Nationality: ' + Nation)

df_player_nationality = pd.DataFrame({
                'PLAYER':PlayerNameList,
                'NATIONALITY':PlayerNationalityList
                })
df_player_nationality
# Out:
# 1321
# Index: 0. Progress: 0.0%. Player: Farizal Marlias, Nationality: Malaysia
# Index: 1. Progress: 0.08%. Player: Izham Tarmizi, Nationality: Malaysia
# Index: 2. Progress: 0.15%. Player: Haziq Nadzli, Nationality: Malaysia
# Index: 3. Progress: 0.23%. Player: Bruno Soares, Nationality: Brazil
# Index: 4. Progress: 0.3%. Player: Marcos António, Nationality: Brazil
# Index: 5. Progress: 0.38%. Player: Adam Nor Azlin, Nationality: Malaysia
# Index: 6. Progress: 0.45%. Player: Aidil Zafuan, Nationality: Malaysia
# Index: 7. Progress: 0.53%. Player: Junior Eldstal, Nationality: Malaysia
# Index: 8. Progress: 0.61%. Player: Dominic Tan, Nationality: Malaysia
# Index: 9. Progress: 0.68%. Player: Fadhli Shas, Nationality: Malaysia
# Index: 10. Progress: 0.76%. Player: Fazly Mazlan, Nationality: Malaysia
# Index: 11. Progress: 0.83%. Player: S. Kunanlan, Nationality: Malaysia
# Index: 12. Progress: 0.91%. Player: Azrif Nasrulhaq, Nationality: Malaysia
# Index: 13. Progress: 0.98%. Player: S. Chanthuru Suppiah, Nationality: Malaysia
# Index: 14. Progress: 1.06%. Player: Hasbullah Abu Bakar, Nationality: Malaysia
# Index: 15. Progress: 1.14%. Player: Afiq Fazail, Nationality: Malaysia
# Index: 16. Progress: 1.21%. Player: Gary Steven, Nationality: Malaysia
# Index: 17. Progress: 1.29%. Player: Natxo Insa, Nationality: Malaysia
# Index: 18. Progress: 1.36%. Player: Nazmi Faiz, Nationality: Malaysia
# Index: 19. Progress: 1.44%. Player: Amirul Hadi Zainal, Nationality: Malaysia
# Index: 20. Progress: 1.51%. Player: Safiq Rahim, Nationality: Malaysia
# Index: 21. Progress: 1.59%. Player: Mohd Shakir, Nationality: Malaysia
# Index: 22. Progress: 1.67%. Player: Brian Ferreira, Nationality: Argentina
# Index: 23. Progress: 1.74%. Player: Gabriel Guerra, Nationality: Argentina
# Index: 24. Progress: 1.82%. Player: Gonzalo Cabrera, Nationality: Argentina
# Index: 25. Progress: 1.89%. Player: Azammuddin Akil, Nationality: Malaysia
# Index: 1299. Progress: 98.33%. Player: Layth Kharoub, Nationality: Palestine
# Index: 1300. Progress: 98.41%. Player: Fazli Ghazali, Nationality: Malaysia
# Index: 1301. Progress: 98.49%. Player: Kyung-hwan Bae, Nationality: Korea, South
# Index: 1302. Progress: 98.56%. Player: Jae-hyeok Chang, Nationality: Korea, South
# Index: 1303. Progress: 98.64%. Player: Faith Obilor, Nationality: Nigeria
# Index: 1304. Progress: 98.71%. Player: Iqbal Azmi, Nationality: Malaysia
# Index: 1305. Progress: 98.79%. Player: Deok Um, Nationality: Korea, South
# Index: 1306. Progress: 98.86%. Player: Chidi Osuchukwu, Nationality: Nigeria
# Index: 1307. Progress: 98.94%. Player: Aremu Timothy, Nationality: Nigeria
# Index: 1308. Progress: 99.02%. Player: Eizrul Ashraf, Nationality: Malaysia
# Index: 1309. Progress: 99.09%. Player: Syakimi Karim, Nationality: Malaysia
# Index: 1310. Progress: 99.17%. Player: Aliyu Abubakar, Nationality: Nigeria
# Index: 1311. Progress: 99.24%. Player: Sang-su An, Nationality: Korea, South
# Index: 1312. Progress: 99.32%. Player: Takumi Sasaki, Nationality: Japan
# Index: 1313. Progress: 99.39%. Player: Ricardo Pires, Nationality: Brazil
# Index: 1314. Progress: 99.47%. Player: Kwang-hui Lee, Nationality: Korea, South
# Index: 1315. Progress: 99.55%. Player: Haziq Mukriz, Nationality: Malaysia
# Index: 1316. Progress: 99.62%. Player: Neto, Nationality: Brazil
# Index: 1317. Progress: 99.7%. Player: Daniel Irfan, Nationality: Malaysia
# Index: 1318. Progress: 99.77%. Player: Aidil Danial, Nationality: Malaysia
# Index: 1319. Progress: 99.85%. Player: Dylan Wenzel-Halls, Nationality: Australia
# Index: 1320. Progress: 99.92%. Player: Rodrigo Dias, Nationality: Brazil
#                   PLAYER NATIONALITY
# 0        Farizal Marlias    Malaysia
# 1          Izham Tarmizi    Malaysia
# 2           Haziq Nadzli    Malaysia
# 3           Bruno Soares      Brazil
# 4         Marcos António      Brazil
# ...                  ...         ...
# 1316                Neto      Brazil
# 1317        Daniel Irfan    Malaysia
# 1318        Aidil Danial    Malaysia
# 1319  Dylan Wenzel-Halls   Australia
# 1320        Rodrigo Dias      Brazil
#
# [1321 rows x 2 columns]

# %%
# Add Nationality

df_msl_player = df_msl_player.merge(df_player_nationality, how='left', on='PLAYER')
df_msl_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3433 entries, 0 to 3432
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SEASON         3433 non-null   object
#  1   TEAM           3433 non-null   object
#  2   TEAM_CLEANED   3433 non-null   object
#  3   PLAYER         3433 non-null   object
#  4   NUMBER         3433 non-null   object
#  5   AGE            3433 non-null   int32
#  6   POSITION       3433 non-null   object
#  7   POSITION_TYPE  3433 non-null   object
#  8   VALUE_EUR      3433 non-null   float64
#  9   PLAYER_LINK    3433 non-null   object
#  10  NATIONALITY    3433 non-null   object
# dtypes: float64(1), int32(1), object(9)
# memory usage: 281.7+ KB

# %%
# Export the DataFrame to csv file

df_msl_player.to_csv(path_csv_datascraping + '\\MSL_FullData.csv', index=False)
df_msl_player.to_csv(path_csv_dataanalysis + '\\MSL_FullData.csv', index=False)
